# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=sale"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
# your code here
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#              sku                                               name  \
# 0  JA222G0VA-K11     JJILIAM JJORIGINAL - Jeans Skinny - blue denim
# 1  PI922SA07-Q13                      veste en sweat zippée - black
# 2  LA212O06W-A11           LEROND - Baskets basses - white/navy/red
# 3  PU142A11O-A12       Chaussures de basket - puma white-puma white
# 4  NE352B0MJ-Q11  9FORTY MLB LOS ANGELES DODGERS  - Casquette - ...
#
#                                                sizes  \
# 0  [27x30, 28x30, 29x30, 29x32, 30x30, 30x32, 30x...
# 1              [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL]
# 2  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 46,...
# 3  [39, 40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45,...
# 4                                         [One Size]
#
#                                              url_key  \
# 0  jack-and-jones-jjiliam-jjoriginal-jeans-skinny...
# 1           pier-one-sweat-zippe-black-pi922sa07-q13
# 2  lacoste-lerond-baskets-basses-whitenavyred-la2...
# 3  puma-chaussures-de-basket-puma-white-puma-whit...
# 4  new-era-9forty-mlb-los-angeles-dodgers-casquet...
#
#                                                media    brand_name  \
# 0  [{'path': 'spp-media-p1/61cf96c837723db1892137...  Jack & Jones
# 1  [{'path': 'spp-media-p1/61e297ed0b8b30d5b6b692...      Pier One
# 2  [{'path': 'spp-media-p1/615139e109fc3767a967e9...       Lacoste
# 3  [{'path': 'spp-media-p1/5f7d6b06a5103f9c970887...          Puma
# 4  [{'path': 'spp-media-p1/ac87d754052833ac8b4248...       New Era
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group  \
# 0  [{'key': 'discountRate', 'value': 'Jusqu’à -10...      clothing
# 1  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 2  [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 3  [{'key': 'discountRate', 'value': '-62%', 'tra...          shoe
# 4  [{'key': 'discountRate', 'value': '-30%', 'tra...   accessoires
#
#                                              outfits delivery_promises  \
# 0  [{'id': '4LkTduB9R6-', 'url_key': '/outfits/4L...                []
# 1                                                NaN                []
# 2                                                NaN                []
# 3                                                NaN                []
# 4                                                NaN                []
#
#   price.original price.promotional  price.has_different_prices  \
# 0        49,99 €           44,99 €                        True
# 1        29,99 €           22,49 €                       False
# 2        94,95 €           70,95 €                       False
# 3       130,00 €           49,95 €                       False
# 4        19,95 €           13,95 €                       False
#
#    price.has_different_original_prices  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    price.has_different_promotional_prices  \
# 0                                    True
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False

# %%
results
# Out:
# {'total_count': 54824,
#  'pagination': {'page_count': 653, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'JA222G0VA-K11',
#    'name': 'JJILIAM JJORIGINAL - Jeans Skinny - blue denim',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '44,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27x30',
#     '28x30',
#     '29x30',
#     '29x32',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x32',
#     '33x34',
#     '34x32',
#     '34x34',
#     '36x32',
#     '36x34'],
#    'url_key': 'jack-and-jones-jjiliam-jjoriginal-jeans-skinny-blue-denim-ja222g0va-k11',
#    'media': [{'path': 'spp-media-p1/61cf96c837723db18921374c879d1139/65df0db3c8fa43e5a558a54552fcbb2b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/3e2c054c2d693be5ac9a86f567bc3063/d4b2988464f3403a972ad59230d5ecbd.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'outfits': [{'id': '4LkTduB9R6-',
#      'url_key': '/outfits/4LkTduB9R6-',
#      'media': [{'path': '2f1f8c38eb9c43e6afa9f6c26faf2557/b4fc7c29000f4cb3af4afa1a7689939b.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'men',
#      'creator': {'id': '7db22afa-7855-44c5-bf83-6114cde8a0b2',
#       'name': 'fabianlueck',
#       'media': [{'path': '7293665acd834474922af94a0c23c2ea/11fb822015434347a99a233a16c0f95b.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'BL522D058-K11'},
#       {'id': 'JA222G0VA-K11'},
#       {'id': 'F1412O006-C11'}]}],
#    'delivery_promises': []},
#   {'sku': 'PI922SA07-Q13',
#    'name': 'veste en sweat zippée - black',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '22,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL', '4XL', '5XL'],
#    'url_key': 'pier-one-sweat-zippe-black-pi922sa07-q13',
#    'media': [{'path': 'spp-media-p1/61e297ed0b8b30d5b6b6927f19b45cba/3c33211ed73547c4ba7f2c71c0af4fc2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/e75c22e5d60d3e63999de538eca4ab0f/fb5d3722bb2e417d8d1c79c781652f1f.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA212O06W-A11',
#    'name': 'LEROND - Baskets basses - white/navy/red',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '70,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '47'],
#    'url_key': 'lacoste-lerond-baskets-basses-whitenavyred-la212o06w-a11',
#    'media': [{'path': 'spp-media-p1/615139e109fc3767a967e9fdd06d7259/266a5283c4464fabb13c90ded04a388b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PU142A11O-A12',
#    'name': 'Chaussures de basket - puma white-puma white',
#    'price': {'original': '130,00\xa0€',
#     'promotional': '49,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '47',
#     '48.5',
#     '49.5',
#     '51'],
#    'url_key': 'puma-chaussures-de-basket-puma-white-puma-white-pu142a11o-a12',
#    'media': [{'path': 'spp-media-p1/5f7d6b06a5103f9c970887a689fc87e5/7e4845e4a6e14d6a8181d5ff928080fe.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-62%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NE352B0MJ-Q11',
#    'name': '9FORTY MLB LOS ANGELES DODGERS  - Casquette - black',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '13,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'new-era-9forty-mlb-los-angeles-dodgers-casquette-black-ne352b0mj-q11',
#    'media': [{'path': 'spp-media-p1/ac87d754052833ac8b4248d6d5b08126/da7c7f66804246f9b3e2e3050d597dc6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/a446cd192d8534f8bcd062f81192cb5c/85a7f654116e480382a6a4aa289089e9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'New Era',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'AD115O0J1-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/lush red',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115o0j1-a11',
#    'media': [{'path': 'spp-media-p1/526dc56766f53368b56260be756990bc/a9dfcff3a3bb4367bc1f8c98de797e40.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'JA222G0HV-C11',
#    'name': 'JJILIAM JJORIGINAL  - Jeans Skinny - grey denim',
#    'price': {'original': '49,99\xa0€',
#     'promotional': '39,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['26x30',
#     '26x32',
#     '27x30',
#     '27x32',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '36x32',
#     '36x34'],
#    'url_key': 'jack-jones-jeans-skinny-grey-denim-ja222g0hv-c11',
#    'media': [{'path': 'spp-media-p1/698439bc0c2139c78984f9d8bfa5b3e1/c925897a11cc49e1938f79c440ca3c35.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/e72541196a08350dbc2c7b05188be1b3/e125a8a7e0a94a6c95d53aeedffe78b2.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD115B01K-A12',
#    'name': 'STAN SMITH - Baskets basses - ftwr white/core white/green',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '85,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3',
#     '50 2/3',
#     '51 1/3',
#     '52 2/3',
#     '53 1/3',
#     '54 2/3',
#     '55 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad115b01k-a12',
#    'media': [{'path': 'spp-media-p1/9dd5dcad89443983b49d7b8576fd712b/3dc23f9aa0394ec39440fd8b4015fe7c.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO122O02W-K11',
#    'name': 'NEW STRETCH TEE C-NECK - T-shirt basique - navy blazer',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tommy-hilfiger-t-shirt-basique-navy-blazer-to122o02w-k11',
#    'media': [{'path': 'spp-media-p1/eadc48a42f243f71930245294c48b678/bf33ace5d50548aca4fa4bd56f77db25.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/204d8652ec3a3676a28f91a0e31b3941/1a2cd3718ba741efafae5d2aeed1fc7b.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'OS322O0O7-K11',
#    'name': 'ONSJAMIE LIFE SS STRIPE REG TEE NOO - T-shirt imprimé - dark navy',
#    'price': {'original': '14,99\xa0€',
#     'promotional': '13,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'only-and-sons-onsjamie-stripe-tee-t-shirt-imprime-dark-navy-os322o0o7-k11',
#    'media': [{'path': 'spp-media-p1/37264f5580943d0c9183f13cab777346/4098a2fba1e749d1a4ff93adb9985cf8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/0827a833fe58396c8f9e88c7db337d9c/081fca2379d44b93aec563127bb4d7a5.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO112O00Z-Q11',
#    'name': 'ICONIC LONG LACE - Baskets basses - black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '53,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40', '41', '42', '43', '44', '46', '48'],
#    'url_key': 'tommy-hilfiger-iconic-long-lace-baskets-basses-to112o00z-q11',
#    'media': [{'path': 'spp-media-p1/d2ef0913d3df33da8cfe6e2c00d5045b/6302490d009842af9c5319b27410d8ab.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'OS322O0RE-Q11',
#    'name': 'ONSNATE REG TANK 2PACK - Débardeur - black/white',
#    'price': {'original': '12,99\xa0€',
#     'promotional': '10,79\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'M', 'L', 'XL'],
#    'url_key': 'only-and-sons-onsnate-reg-tank-2pack-debardeur-blackwhite-os322o0re-q11',
#    'media': [{'path': 'spp-media-p1/a375884482663641b80895932e96b04e/8a61a13fbe364ef9816f2e97bb9d2e23.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'spp-media-p1/270ab1bb94b53e858270708350e4e19c/8ba0f7eaab374561a5a2d618694ceab0.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-17%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PUC22G0BZ-K15',
#    'name': 'Jean slim - dark-blue denim',
#    'price': {'original': '19,99\xa0€',
#     'promotional': '13,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '40', '42', '44', '46'],
#    'url_key': 'pullandbear-jean-slim-dark-blue-denim-puc22g0bz-k15',
#    'media': [{'path': 'spp-media-p1/7314104cbcd23e7e986d09ac08fc86ec/db137cd83220418d9d06eff1f0b1e980.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/3cc944192f1f398a94e3990c8a4f9562/b9040d0ac39449bd8098e0ebea268309.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'PULL&BEAR',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PU112O04B-K11',
#    'name': 'FUTURE RIDER PLAY ON UNISEX - Baskets basses - black/fluo green/dazzling blue',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '59,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '41',
#     '42',
#     '43',
#     '44',
#     '45',
#     '48.5'],
#    'url_key': 'puma-rider-baskets-basses-blackfluo-greendazzling-blue-pu112o04b-k11',
#    'media': [{'path': 'spp-media-p1/783da918be033301bc8e4fa4b57f8626/c3c57d161f9d460ea1029591aa7db286.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'spp-media-p1/648058a84cab371f99451f615228d919/f606f46c1d9744589beceaf28fc8414e.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'mu_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE252D02R-Q11',
#    'name': 'NEW DUNCAN - Ceinture - regular black',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['75', '80', '85', '90', '95', '100', '105', '110', '115'],
#    'url_key': 'levisr-ceinture-regular-black-le252d02r-q11',
#    'media': [{'path': 'spp-media-p1/b57f58a3277b3e75aa4d0e700a979cac/d08c043dd06e4ddeaaade4f256b871dd.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/b3c75c5ebf1e3eebb75f1d5d887a91f5/c97b348b7224414bb37669961ed0a51e.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'JA222T0B6-Q11',
#    'name': 'JJEROCKY JACKET - Veste en similicuir - black',
#    'price': {'original': '59,99\xa0€',
#     'promotional': '53,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'jack-and-jones-jcorocky-jacket-veste-en-similicuir-black-ja222t0b6-q11',
#    'media': [{'path': 'spp-media-p1/0433c37a5f963375a136c77c78cf29dd/88678b3dad884911811229c548856689.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/780fa9d01962367b8d4d3c3968250d33/ad54afd6a4564f14a75ad8e8d72b544f.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD115O0IY-A11',
#    'name': 'TEAM COURT - Baskets basses - ftwwht/cblack/ftwwht',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '52,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-team-court-baskets-basses-ad115o0iy-a11',
#    'media': [{'path': 'spp-media-p1/f89e95c5e7d438889bd47d702cf46ad3/653c925c3b4e43588078d7564d4d0314.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NE212O04G-K12',
#    'name': '574 - Baskets basses - marblehead pigment (ML574EAD)',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '70,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '39.5',
#     '40',
#     '40.5',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46.5',
#     '47.5'],
#    'url_key': 'new-balance-574-baskets-basses-greynavy-ne212o04g-k12',
#    'media': [{'path': 'spp-media-p1/a9193f5ce4953e3387e16439b0160d01/e0121bd5b3b5408daa5cfe7f010c4e81.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'New Balance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PI952H04U-K11',
#    'name': 'Mallette - dark blue/beige',
#    'price': {'original': '43,99\xa0€',
#     'promotional': '19,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'pier-one-sac-ordinateur-dark-bluebeige-pi952h04u-k11',
#    'media': [{'path': 'spp-media-p1/7a3b3d9ee3ca327e86c984aeec591cd1/d4a5c742c3eb419480764b60e4bff309.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/d57a40b0d75b31209e8c9a8d5ddabcba/770616fce0314f8bb361236ef01cf958.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-55%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'GS122E07J-C12',
#    'name': 'ROVIC ZIP 3D STRAIGHT TAPERED - Pantalon cargo - grey',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27x30',
#     '27x32',
#     '27x34',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '30x36',
#     '31x30',
#     '31x32',
#     '31x34',
#     '31x36',
#     '31x38',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '32x38',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '33x38',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '34x38',
#     '36x30',
#     '36x32',
#     '36x34',
#     '36x36',
#     '36x38',
#     '38x30',
#     '38x32',
#     '38x34',
#     '38x36',
#     '38x38',
#     '40x32',
#     '40x34',
#     '40x36'],
#    'url_key': 'g-star-rovic-zip-3d-tapered-pantalon-cargo-gs122e07j-c12',
#    'media': [{'path': 'spp-media-p1/a85e287c242334f18d150a38fc36a287/5ee3d1a1799a45498b95d63c317ce0c9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/9457cce30487353aad4cc02d8e24d331/04eea11f09d24d5cba8ca71cab051adc.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'G-Star',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'IJ022E023-Q12',
#    'name': 'AKKAD - Chino - black',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '24,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['29x34',
#     '30x34',
#     '31x32',
#     '31x34',
#     '32x32',
#     '33x32',
#     '34x32',
#     '34x34',
#     '36x32',
#     '38x32'],
#    'url_key': 'indicode-jeans-akkad-chino-black-ij022e023-q12',
#    'media': [{'path': 'spp-media-p1/b8a106f59e253bf19b49580fc8af9e1d/3ce2aaad04bf487ea28e500bfa454506.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'INDICODE JEANS',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-38%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PU112B04W-Q11',
#    'name': 'SMASH L - Baskets basses - black/dark shadow',
#    'price': {'original': '55,00\xa0€',
#     'promotional': '37,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '44',
#     '44.5'],
#    'url_key': 'puma-smash-l-baskets-basses-pu112b04w-q11',
#    'media': [{'path': 'spp-media-p1/990c68a8962e39898745aedc604b1657/00eacd1a32494a3b8536e2fd25346366.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-31%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO122T051-K11',
#    'name': 'Veste sans manches - sky captain',
#    'price': {'original': '179,95\xa0€',
#     'promotional': '134,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'tommy-hilfiger-veste-sans-manches-sky-captain-to122t051-k11',
#    'media': [{'path': 'spp-media-p1/ee3c89b5add93dfbb8b720e3c37626cf/43c87d01968e4158949e9f551f1bab81.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/0913e7afaad03e5ab4a3704c6cfa832e/9383918e8a414409aecc6bc7056e2431.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JA222G13Z-K11',
#    'name': 'JJILIAM JJORIGINAL  - Jeans Skinny - blue denim',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '29,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x30',
#     '29x30',
#     '29x32',
#     '30x30',
#     '30x32',
#     '31x30',
#     '31x32',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '36x32',
#     '36x34'],
#    'url_key': 'jack-and-jones-jjiliam-jjoriginal-jean-slim-blue-denim-ja222g13z-k11',
#    'media': [{'path': 'spp-media-p1/ebf024b4da05350dbba63cda705477ec/d200b216387443c89f17e05620033c1d.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/640b991de254330ab11a4c1db7324172/f71fb61a18ac4ff2a0ff6fac813f02ec.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CO412A04J-502',
#    'name': 'CHUCK TAYLOR ALL STAR HI - Baskets montantes - navy',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35',
#     '36',
#     '36.5',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '39.5',
#     '40',
#     '41',
#     '41.5',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46',
#     '46.5',
#     '48',
#     '49',
#     '50',
#     '51.5',
#     '53',
#     '54'],
#    'url_key': 'converse-baskets-montantes-bleu-co412a04j-502',
#    'media': [{'path': 'spp-media-p1/752cb0ad396f32b59c9b65d8f3c2ede0/3f34a0beb1144db99bb8a541cb1d82a7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': '_tvFlJDlTBi',
#      'url_key': '/outfits/_tvFlJDlTBi',
#      'media': [{'path': 'cf997312f52b4e63bb0ceaff0367847f/773f5f74f62749d5b1f487b1ae232ebd.jpg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'men',
#      'creator': {'id': '72318c48-e7d8-4cad-8ff8-c047d0c13fcf',
#       'name': 'blvckxkev',
#       'media': [{'path': '58da0eb9713945ecb4f23a2d922c6806/c7aa9f11616c4c91b02f76b20da1c5d9.jpeg',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'NIJ22S00Q-K11'},
#       {'id': 'A0F22F00L-N11'},
#       {'id': 'CO412A04J-502'}]}],
#    'delivery_promises': []},
#   {'sku': 'AD115O0BD-A11',
#    'name': 'AMERICANA - Baskets basses - footwear white/collegiate royal/scarlet',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '63,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '42',
#     '44',
#     '46',
#     '48',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3',
#     '40 2/3',
#     '41 1/3',
#     '42 2/3',
#     '43 1/3',
#     '44 2/3',
#     '45 1/3',
#     '46 2/3',
#     '47 1/3',
#     '48 2/3',
#     '49 1/3'],
#    'url_key': 'adidas-originals-americana-baskets-basses-footwear-whitecollegiate-royalscarlet-ad115o0bd-a11',
#    'media': [{'path': 'spp-media-p1/f42ca9768edf3af6bca1ba1ef905ba5c/6ff3a1dc8a9b4a04863602891c7e1756.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PUC21A0BN-Q11',
#    'name': 'Pantalon de survêtement - black',
#    'price': {'original': '15,99\xa0€',
#     'promotional': '12,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L'],
#    'url_key': 'pullandbear-pantalon-de-survetement-black-puc21a0bn-q11',
#    'media': [{'path': 'spp-media-p1/7712a5d002bd36d5a7d1c23185dd623e/32e0519c24324edfabcb1b870317085d.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/1b60166d7e453badbaa6d8cb7520c006/67a4778afd6a4ef1a30eee8e32606d45.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'PULL&BEAR',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-19%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PU144A07R-A13',
#    'name': 'Baskets basses - white-black',
#    'price': {'original': '110,00\xa0€',
#     'promotional': '44,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '37',
#     '37.5',
#     '38',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '46'],
#    'url_key': 'puma-baskets-basses-white-black-pu144a07r-a13',
#    'media': [{'path': 'spp-media-p1/f3368c2299a1303d84427b6386c6d74a/9902e2ca8ceb4163a1183c1247d95f3d.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-59%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA222D01Z-002',
#    'name': 'T-shirt basique - white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-t-shirt-basique-blanc-la222d01z-002',
#    'media': [{'path': 'spp-media-p1/a395079976fa3833b882f2ed7def9e50/ea47947b2e974067b9ec0688d2534c85.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/19636a9d99b332b483c1f3c9589fe187/18bb62587cb94e9a8768dd1893fc5aea.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JA222E0LH-C11',
#    'name': 'JJIMARCO JBOWIE - Chino - drizzle',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '27,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27x32',
#     '28x30',
#     '28x32',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '36x32',
#     '36x34',
#     '36x36'],
#    'url_key': 'jack-and-jones-jjimarco-jbowie-chino-drizzle-ja222e0lh-c11',
#    'media': [{'path': 'spp-media-p1/1975c2a91ebc3bc79fe29b040f335ac8/6997e333493f41d6918f415889d21cbb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/5b002ac3706d30cbaf17102c04a1232a/7c811a99cf1a4a4985c72e9840265efa.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JA222G13G-K11',
#    'name': 'JJILIAM JJORIGINAL  - Jean slim - blue denim',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '35,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x30',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '34x32',
#     '34x34',
#     '34x36',
#     '36x30',
#     '36x32',
#     '36x34'],
#    'url_key': 'jack-and-jones-jjiliam-jjoriginal-jean-slim-blue-denim-ja222g13g-k11',
#    'media': [{'path': 'spp-media-p1/2646ed0e27b83caf939bfd5ece193065/a135aab25db94334a69f6afe05bd0564.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/b862a064c407333a8f96c0a329560fb9/f73b78fe7be342f0a4edfa0584a88da1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO122S06Q-K13',
#    'name': 'LOGO HOODY - Sweat à capuche - blue',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tommy-hilfiger-logo-hoody-sweatshirt-to122s06q-k13',
#    'media': [{'path': 'spp-media-p1/0138f880eecd342c903328aad0c5b4a2/90a63f8537d94717adbb0b58bee144ec.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/8094fefafb793fc992e488b36b7ab727/bfba9ad844b84bfa813fe44b5b85a0cb.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'OS322E04A-Q11',
#    'name': 'ONSMARK PANT - Pantalon classique - black',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '35,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '34x32',
#     '34x34',
#     '36x32',
#     '36x34'],
#    'url_key': 'only-and-sons-onsmark-pant-pantalon-classique-os322e04a-q11',
#    'media': [{'path': 'spp-media-p1/1dd0155588f73e62bbc24f213935dab9/adc49a97e15f4d2388f7ff0aaf437773.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/948b06289d78394598a874c45a85c1b1/ffaf2f80237f44b584bfc19c2eab8ad7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PI912M08M-Q11',
#    'name': 'Derbies & Richelieus - black',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '21,29\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['41', '42', '43', '44', '45', '46', '47', '48'],
#    'url_key': 'pier-one-derbies-black-pi912m08m-q11',
#    'media': [{'path': 'spp-media-p1/9265cfde7ae03b688c20f12b93caf76b/dafb385067a549b197040c4b577bcdcb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'FS152E029-D11',
#    'name': 'DECKER - Montre à aiguilles - silver-coloured',
#    'price': {'original': '149,00\xa0€',
#     'promotional': '75,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'fossil-decker-montre-a-aiguilles-silver-coloured-fs152e029-d11',
#    'media': [{'path': 'spp-media-p1/805b4ae05ad8386ca7112e104d0ca5e0/02bfb138d5e94ad78c886c3012a86518.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'spp-media-p1/0440488736fe3e8a9e95d01e7c53de0d/44e8aca2fc4a47ec813a7fe3eca88c51.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Fossil',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI122F043-Q11',
#    'name': 'CLUB - Short - black/white',
#    'price': {'original': '27,95\xa0€',
#     'promotional': '25,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL', '4XL'],
#    'url_key': 'nike-sportswear-club-short-blackwhite-ni122f043-q11',
#    'media': [{'path': 'spp-media-p1/09b203c2fb513647acda448ea59425e5/3318e7553d5a4b9788b8a792d29f5c17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/3908c037ae3d3ba49aadee3f997485d7/fa429bf308844cdfa5e25f704b358492.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': '47B52P00I-Q11',
#    'name': 'NEW YORK YANKEES - Casquette - black',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '13,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': '47-new-york-yankees-casquette-black-47b52p00i-q11',
#    'media': [{'path': 'spp-media-p1/a8529a2283863260ab3dcbd99f8208a3/409b81019b7140b0bed53c9e2d56e525.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/75bdbd14f6d831b6b32bd65c51573775/574105c716d14c9d88a71ec8b17ce05f.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "'47",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI122O0CW-Q12',
#    'name': 'T-shirt imprimé - black/university red',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '15,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'nike-sportswear-t-shirt-imprime-blackuniversity-red-ni122o0cw-q12',
#    'media': [{'path': 'spp-media-p1/f2bdc5ff3eb530a0b1804e9dbde9906a/b691f793e56847658538bdca04a12082.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/52ed85265cc53e738a96a1bba3b881cd/a1ef57b3165d48e5b7583f64b4e93e1e.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'IJ022O047-A11',
#    'name': 'EBEL - T-shirt imprimé - optical white',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '7,20\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'indicode-jeans-ebel-t-shirt-imprime-optical-white-ij022o047-a11',
#    'media': [{'path': 'spp-media-p1/aa0d9d3b67df37a9bf758a7db69b3c82/d00cf6b01bf94990976cc7b5a9428b17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/3b7794715077342b8410a743863cfbdb/99203422b412428d8abb8022e9a54c8a.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'INDICODE JEANS',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-60%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PI922SA08-Q13',
#    'name': 'Sweat à capuche - black',
#    'price': {'original': '24,99\xa0€',
#     'promotional': '18,69\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XXL', '3XL', '4XL', '5XL', '6XL'],
#    'url_key': 'pier-one-sweat-a-capuche-black-pi922sa08-q13',
#    'media': [{'path': 'spp-media-p1/54247209cdba392a900e6d4c2ec33d10/8a01a4a7108f4cf4a853acaf617b72a0.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/b6971ecd9d3737a296a28e4816756126/819525b43cab43878765d1c2b0c891f6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO122P03I-K11',
#    'name': 'SLIM FIT - Polo - sky captain',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '48,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tommy-hilfiger-polo-sky-captain-to122p03i-k11',
#    'media': [{'path': 'spp-media-p1/9a731462e3f13f9f85e1da421f807399/2a6984b327aa4266a68da225e32a41a6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/1f84c36aea2b3a3a956af387d29cf33e/059cc8bb96fa4263afd74b980e578c63.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO152B00S-Q11',
#    'name': 'CLASSIC - Casquette - schwarz (15)',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '25,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'tommy-hilfiger-classic-casquette-black-to152b00s-q11',
#    'media': [{'path': 'spp-media-p1/90294d3334933b8d93cff3d032c153ec/4c7e1f0e212c48ab8f3e925feb100df8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'spp-media-p1/61595c96588137439be7a6d4e6bc8530/5a33ac074b19494383f3e1b64e6fe265.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'PI922Q00A-Q11',
#    'name': 'Pullover - black',
#    'price': {'original': '22,99\xa0€',
#     'promotional': '18,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '5XL', '6XL'],
#    'url_key': 'pier-one-pullover-noir-pi922q00a-q11',
#    'media': [{'path': 'spp-media-p1/d46d22bf1cd8326e831ea8c4aa0074ba/49bfb18b428f417fb10aa7720771c4ee.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
# ...
#      'is_family': False},
#     {'key': 'VEF',
#      'label': 'Versace Watches',
#      'family_id': 'VERS',
#      'is_family': False},
#     {'key': 'VB0', 'label': 'Vibram Fivefingers', 'is_family': False},
#     {'key': 'V14', 'label': 'Victorinox', 'is_family': False},
#     {'key': 'VIA', 'label': 'Viggo', 'is_family': False},
#     {'key': 'VI1', 'label': 'Viking', 'is_family': False},
#     {'key': 'VIO', 'label': 'Vintage Supply', 'is_family': False},
#     {'key': 'VIG', 'label': 'Vitaly', 'is_family': False},
#     {'key': 'VIVI', 'label': 'Vivienne Westwood', 'is_family': True},
#     {'key': 'VW9',
#      'label': 'Vivienne Westwood',
#      'family_id': 'VIVI',
#      'is_family': False},
#     {'key': 'VW6',
#      'label': 'Vivienne Westwood Anglomania',
#      'family_id': 'VIVI',
#      'is_family': False},
#     {'key': 'VB7', 'label': 'Voile Blanche', 'is_family': False},
#     {'key': 'V19', 'label': 'Volcom', 'is_family': False},
#     {'key': 'VO7', 'label': 'Volé la lumière', 'is_family': False},
#     {'key': 'WY0', 'label': 'W6YZ', 'is_family': False},
#     {'key': 'W02', 'label': 'Walk London', 'is_family': False},
#     {'key': 'WAJ', 'label': 'WAWWA', 'is_family': False},
#     {'key': 'WEA', 'label': 'We are Cph', 'is_family': False},
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'CLC', 'label': 'Wearcolour', 'is_family': False},
#     {'key': 'WEB', 'label': 'Weekday', 'is_family': False},
#     {'key': 'WEE', 'label': 'Wella EIMI', 'is_family': False},
#     {'key': 'WM1', 'label': 'Wemoto', 'is_family': False},
#     {'key': 'WE1', 'label': 'WeSC', 'is_family': False},
#     {'key': 'WHD', 'label': 'Whamisa', 'is_family': False},
#     {'key': 'WH4', 'label': 'White Mountaineering', 'is_family': False},
#     {'key': 'WIA', 'label': 'Wild Feet', 'is_family': False},
#     {'key': 'WIK', 'label': 'Wild For The Weekend', 'is_family': False},
#     {'key': 'WIC', 'label': 'Wildwuchs Bartpflege', 'is_family': False},
#     {'key': 'WO3', 'label': 'Won Hundred', 'is_family': False},
#     {'key': 'WO4', 'label': 'Wood Wood', 'is_family': False},
#     {'key': 'WOD', 'label': 'Woodbird', 'is_family': False},
#     {'key': 'WR1',
#      'label': 'Wrangler',
#      'family_id': 'WR00',
#      'is_family': False},
#     {'key': 'YN1', 'label': 'Y Not?', 'is_family': False},
#     {'key': 'YE1', 'label': 'Yellow Cab', 'is_family': False},
#     {'key': 'YE9', 'label': 'YETI', 'is_family': False},
#     {'key': 'YO4', 'label': 'YMC You Must Create', 'is_family': False},
#     {'key': 'YO8', 'label': 'YOU & OIL', 'is_family': False},
#     {'key': 'YOA', 'label': 'Young and Reckless', 'is_family': False},
#     {'key': 'YO1',
#      'label': 'YOURTURN',
#      'family_id': 'YOUR',
#      'is_family': False},
#     {'key': 'Z21',
#      'label': 'Zadig & Voltaire',
#      'family_id': 'ZA00',
#      'is_family': False},
#     {'key': 'ZA8',
#      'label': 'Zalando Essentials',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'Z10', 'label': 'Ziener', 'is_family': False},
#     {'key': 'ZI1', 'label': 'Zign', 'family_id': 'ZIGN', 'is_family': False},
#     {'key': 'ZS4', 'label': 'Zimtstern', 'is_family': False},
#     {'key': 'ZIE', 'label': 'Ziq and Yoni', 'is_family': False},
#     {'key': 'ZW1', 'label': 'Zwilling', 'is_family': False},
#     {'key': '47B', 'label': "'47", 'is_family': False},
#     {'key': '111', 'label': '11 DEGREES', 'is_family': False},
#     {'key': 'L19', 'label': '120% Lino', 'is_family': False},
#     {'key': '190', 'label': '1904', 'is_family': False},
#     {'key': '270', 'label': '274', 'is_family': False},
#     {'key': '310', 'label': '3.1 Phillip Lim', 'is_family': False},
#     {'key': '7F1', 'label': '7 for all mankind', 'is_family': False},
#     {'key': '880', 'label': '8848 Altitude', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4,
#     'max': 2396,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'pure_cashmere', 'label': 'cachemire (100%)'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'flanelette', 'label': 'Flanelle chaude'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsabilité',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsabilité'}],
#    'group_id': 'sustainable',
#    'description': 'Retrouvez la planète au cœur même de notre sélection mode et beauté.'},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'camouflage', 'label': 'camouflage'},
#     {'key': 'checked', 'label': 'carreaux'},
#     {'key': 'herring_bone', 'label': 'chevrons'},
#     {'key': 'flecked', 'label': 'chiné'},
#     {'key': 'plain', 'label': 'couleur unie'},
#     {'key': 'gradient', 'label': 'dégradé'},
#     {'key': 'burnout', 'label': 'dévoré'},
#     {'key': 'pinstripe', 'label': 'fines rayures'},
#     {'key': 'floral', 'label': 'floral'},
#     {'key': 'print', 'label': 'imprimé'},
#     {'key': 'animal_print', 'label': 'imprimé animal'},
#     {'key': 'leopard', 'label': 'imprimé léopard'},
#     {'key': 'photo_print', 'label': 'imprimé photo'},
#     {'key': 'colored', 'label': 'multicolore'},
#     {'key': 'paisley', 'label': 'Paisley/cachemire'},
#     {'key': 'striped', 'label': 'rayures'},
#     {'key': 'polka_dot', 'label': 'à pois'}]},
#   {'key': 'lengths',
#    'label': 'Longueur',
#    'url_key': 'length',
#    'kind': 'values',
#    'values': [{'key': 'normal', 'label': 'normale'},
#     {'key': 'extra_short', 'label': 'extra courte'},
#     {'key': 'short', 'label': 'courte'},
#     {'key': 'thigh_length', 'label': 'Longueur mi-cuisse'},
#     {'key': 'knee_length', 'label': 'Jusqu’aux genoux'},
#     {'key': 'calf_length', 'label': 'Longueur midi'},
#     {'key': '3_4_length', 'label': '3/4'},
#     {'key': '7_8_length', 'label': '7/8'},
#     {'key': 'ankle_length', 'label': 'socquettes'},
#     {'key': 'long', 'label': 'longue'},
#     {'key': 'extra_long', 'label': 'extra longue'},
#     {'key': '26', 'label': '26'},
#     {'key': '28', 'label': '28'},
#     {'key': '29', 'label': '29'},
#     {'key': '30', 'label': '30'},
#     {'key': '31', 'label': '31'},
#     {'key': '32', 'label': '32'},
#     {'key': '33', 'label': '33'},
#     {'key': '34', 'label': '34'},
#     {'key': '35', 'label': '35'},
#     {'key': '36', 'label': '36'},
#     {'key': '38', 'label': '38'},
#     {'key': '40', 'label': '40'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'styles',
#    'label': 'Style',
#    'url_key': 'style',
#    'kind': 'values',
#    'values': [{'key': 'casual', 'label': 'casual'},
#     {'key': 'sporty', 'label': 'sportif'},
#     {'key': 'urban', 'label': 'Urbain'}]},
#   {'key': 'trouser_rises',
#    'label': 'Type de taille',
#    'url_key': 'trouser_rise',
#    'kind': 'values',
#    'values': [{'key': 'LOW', 'label': 'basse'},
#     {'key': 'MEDIUM', 'label': 'normale'},
#     {'key': 'HIGH', 'label': 'haute'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 54796,
#  'filter_groups': [],
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Promos',
#    'id': '9191',
#    'url_key': 'promo-homme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-homme/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '9205',
#      'url_key': 'promo-mode-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-homme/?order=sale',
#      'children': [],
#      'article_count': 40990},
#     {'label': 'Chaussures',
#      'id': '9192',
#      'url_key': 'promo-chaussures-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-homme/?order=sale',
#      'children': [],
#      'article_count': 9319},
#     {'label': 'Sport',
#      'id': '13690',
#      'url_key': 'promo-sport-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-homme/?order=sale',
#      'children': [],
#      'article_count': 4813},
#     {'label': 'Accessoires',
#      'id': '9222',
#      'url_key': 'promo-accessoires-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-homme/?order=sale',
#      'children': [],
#      'article_count': 4397},
#     {'label': 'Espace Créateurs',
#      'id': '13825',
#      'url_key': 'promo-luxe-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-homme/?order=sale',
#      'children': [],
#      'article_count': 3172},
#     {'label': 'Beauté',
#      'id': '13865',
#      'url_key': 'beaute-homme-soins-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-homme-soins-promo/?order=sale',
#      'children': [],
#      'article_count': 233}],
#    'article_count': 54798}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Homme',
#      'url_key': 'homme',
#      'full_url': '/homme/?order=sale'},
#     {'label': 'Promos',
#      'url_key': 'promo-homme',
#      'full_url': '/promo-homme/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-homme',
#       'url_key': 'promo-homme',
#       'label': 'Promos',
#       'seo_label': 'Promos homme',
#       'reset_url': '/?order=sale',
#       'id': '9191'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-homme/?order=sale',
#   'reset_url': '/promo-homme/?order=sale',
#   'app_url': '?urlKey=promo-homme&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-homme',
#     'url_key': 'promo-homme',
#     'label': 'Promos',
#     'seo_label': 'Promos homme',
#     'reset_url': '/?order=sale',
#     'id': '9191'}]},
#  'selectedFilters': {'categories': ['promo-homme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False,
#   'lazyArticleImages': False,
#   'useImg01': True},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'search-dialog-mobile': [14],
#   'search-dialog-mobile-premium': [10],
#   'search-dialog-fullwidth': [24],
#   'search-dialog-premium': [16],
#   'search-dialog': [18],
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43],
#   'style-profile-follow-brands-banner': 6,
#   'style-profile-follow-brands-banner-mobile': 4,
#   'ingrid-teaser': 6,
#   'ingrid-premium-teaser': 5,
#   'ingrid-mobile-teaser': 4,
#   'ingrid-premium-mobile-teaser': 3},
#  'prideEnabled': False,
#  'lazyArticleImages': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'teaser': None,
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
total_pages = results["pagination"]["page_count"]
total_pages
# Out:
# 653

# %%
df = pd.DataFrame()
for i in range(30):
    k= 84*i
    url = f"https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={84}&sort=sale"
    response = urllib.request.urlopen(url)
    results = json.load(response)
    data = json_normalize(results)
    data1 = json_normalize(data.articles[0])
    data1 = data1.set_index('sku')
    df = df.append(data1)
    print(f"getting page {i} of {total_pages}", end='\r')
    
df.head()
# Out:
# getting page 29 of 653
#                                                             name  \
# sku
# JA222G0VA-K11     JJILIAM JJORIGINAL - Jeans Skinny - blue denim
# PI922SA07-Q13                      veste en sweat zippée - black
# LA212O06W-A11           LEROND - Baskets basses - white/navy/red
# PU142A11O-A12       Chaussures de basket - puma white-puma white
# NE352B0MJ-Q11  9FORTY MLB LOS ANGELES DODGERS  - Casquette - ...
#
#                                                            sizes  \
# sku
# JA222G0VA-K11  [27x30, 28x30, 29x30, 29x32, 30x30, 30x32, 30x...
# PI922SA07-Q13              [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL]
# LA212O06W-A11  [40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45, 46,...
# PU142A11O-A12  [39, 40, 40.5, 41, 42, 42.5, 43, 44, 44.5, 45,...
# NE352B0MJ-Q11                                         [One Size]
#
#                                                          url_key  \
# sku
# JA222G0VA-K11  jack-and-jones-jjiliam-jjoriginal-jeans-skinny...
# PI922SA07-Q13           pier-one-sweat-zippe-black-pi922sa07-q13
# LA212O06W-A11  lacoste-lerond-baskets-basses-whitenavyred-la2...
# PU142A11O-A12  puma-chaussures-de-basket-puma-white-puma-whit...
# NE352B0MJ-Q11  new-era-9forty-mlb-los-angeles-dodgers-casquet...
#
#                                                            media  \
# sku
# JA222G0VA-K11  [{'path': 'spp-media-p1/61cf96c837723db1892137...
# PI922SA07-Q13  [{'path': 'spp-media-p1/61e297ed0b8b30d5b6b692...
# LA212O06W-A11  [{'path': 'spp-media-p1/615139e109fc3767a967e9...
# PU142A11O-A12  [{'path': 'spp-media-p1/5f7d6b06a5103f9c970887...
# NE352B0MJ-Q11  [{'path': 'spp-media-p1/ac87d754052833ac8b4248...
#
#                  brand_name  is_premium family_articles  \
# sku
# JA222G0VA-K11  Jack & Jones       False              []
# PI922SA07-Q13      Pier One       False              []
# LA212O06W-A11       Lacoste       False              []
# PU142A11O-A12          Puma       False              []
# NE352B0MJ-Q11       New Era       False              []
#
#                                                            flags  \
# sku
# JA222G0VA-K11  [{'key': 'discountRate', 'value': 'Jusqu’à -10...
# PI922SA07-Q13  [{'key': 'discountRate', 'value': '-25%', 'tra...
# LA212O06W-A11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# PU142A11O-A12  [{'key': 'discountRate', 'value': '-62%', 'tra...
# NE352B0MJ-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...
#
#               product_group  \
# sku
# JA222G0VA-K11      clothing
# PI922SA07-Q13      clothing
# LA212O06W-A11          shoe
# PU142A11O-A12          shoe
# NE352B0MJ-Q11   accessoires
#
#                                                          outfits  \
# sku
# JA222G0VA-K11  [{'id': '4LkTduB9R6-', 'url_key': '/outfits/4L...
# PI922SA07-Q13                                                NaN
# LA212O06W-A11                                                NaN
# PU142A11O-A12                                                NaN
# NE352B0MJ-Q11                                                NaN
#
#               delivery_promises price.original price.promotional  \
# sku
# JA222G0VA-K11                []        49,99 €           44,99 €
# PI922SA07-Q13                []        29,99 €           22,49 €
# LA212O06W-A11                []        94,95 €           70,95 €
# PU142A11O-A12                []       130,00 €           49,95 €
# NE352B0MJ-Q11                []        19,95 €           13,95 €
#
#                price.has_different_prices  \
# sku
# JA222G0VA-K11                        True
# PI922SA07-Q13                       False
# LA212O06W-A11                       False
# PU142A11O-A12                       False
# NE352B0MJ-Q11                       False
#
#                price.has_different_original_prices  \
# sku
# JA222G0VA-K11                                False
# PI922SA07-Q13                                False
# LA212O06W-A11                                False
# PU142A11O-A12                                False
# NE352B0MJ-Q11                                False
#
#                price.has_different_promotional_prices  \
# sku
# JA222G0VA-K11                                    True
# PI922SA07-Q13                                   False
# LA212O06W-A11                                   False
# PU142A11O-A12                                   False
# NE352B0MJ-Q11                                   False
#
#                price.has_discount_on_selected_sizes_only
# sku
# JA222G0VA-K11                                      False
# PI922SA07-Q13                                      False
# LA212O06W-A11                                      False
# PU142A11O-A12                                      False
# NE352B0MJ-Q11                                      False

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

# %%
df.brand_name.value_counts().head()
# Out:
# Jack & Jones        390
# Pier One            300
# Tommy Hilfiger      240
# Puma                180
# adidas Originals    152
# Name: brand_name, dtype: int64

# %%
df["price.original"] = df["price.original"].str.replace(",",".")
df["price.original"] = df["price.original"].str.replace("€","").str.strip()

df["price.promotional"] = df["price.promotional"].str.replace(",",".")
df["price.promotional"] = df["price.promotional"].str.replace("€","").str.strip()

# %%
df["discount"]= 100 - ((df['price.promotional'].astype(float)*100)/df['price.original'].astype(float))

# %%
df1 = df[["name","brand_name","price.original","price.promotional","discount"]].copy()
df1.head()
# Out:
#                                                             name  \
# sku
# JA222G0VA-K11     JJILIAM JJORIGINAL - Jeans Skinny - blue denim
# PI922SA07-Q13                      veste en sweat zippée - black
# LA212O06W-A11           LEROND - Baskets basses - white/navy/red
# PU142A11O-A12       Chaussures de basket - puma white-puma white
# NE352B0MJ-Q11  9FORTY MLB LOS ANGELES DODGERS  - Casquette - ...
#
#                  brand_name price.original price.promotional   discount
# sku
# JA222G0VA-K11  Jack & Jones          49.99             44.99  10.002000
# PI922SA07-Q13      Pier One          29.99             22.49  25.008336
# LA212O06W-A11       Lacoste          94.95             70.95  25.276461
# PU142A11O-A12          Puma         130.00             49.95  61.576923
# NE352B0MJ-Q11       New Era          19.95             13.95  30.075188

# %%
df1.sort_values(by = "discount", ascending = False).head()
# Out:
#                                                        name brand_name  \
# sku
# PU142A11O-A12  Chaussures de basket - puma white-puma white       Puma
# PU142A11O-A12  Chaussures de basket - puma white-puma white       Puma
# PU142A11O-A12  Chaussures de basket - puma white-puma white       Puma
# PU142A11O-A12  Chaussures de basket - puma white-puma white       Puma
# PU142A11O-A12  Chaussures de basket - puma white-puma white       Puma
#
#               price.original price.promotional   discount
# sku
# PU142A11O-A12         130.00             49.95  61.576923
# PU142A11O-A12         130.00             49.95  61.576923
# PU142A11O-A12         130.00             49.95  61.576923
# PU142A11O-A12         130.00             49.95  61.576923
# PU142A11O-A12         130.00             49.95  61.576923

# %%
sum_original=df1['price.original'].astype(float).sum()
sum_discount=df1['price.promotional'].astype(float).sum()
total_disc= sum_discount/sum_original
total_disc
# Out:
# 0.7338461002483492
