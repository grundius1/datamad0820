# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=sale"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
# your code here
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#              sku                                               name  \
# 0  OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# 1  JA222S1BM-C11  JORNEWSHAKEDOWN BLOCK ZIP  - veste en sweat zi...
# 2  JA222G0VA-K11     JJILIAM JJORIGINAL - Jeans Skinny - blue denim
# 3  PI922Q00S-C12                                       Gilet - grey
# 4  CF522G03J-K11                        ROSLONE - Jean droit - blue
#
#                                                sizes  \
# 0  [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# 1                                      [S, M, L, XL]
# 2  [27x30, 27x32, 28x30, 29x30, 29x32, 29x34, 30x...
# 3                            [XS, S, M, L, XXL, 6XL]
# 4                           [36, 38, 40, 42, 44, 46]
#
#                                              url_key  \
# 0     only-and-sons-onsmark-pant-chino-os322e04a-k12
# 1  jack-and-jones-jornewshakedown-block-zip-veste...
# 2  jack-and-jones-jjiliam-jjoriginal-jeans-skinny...
# 3                  pier-one-gilet-grey-pi922q00s-c12
# 4        celio-roslone-jean-droit-blue-cf522g03j-k11
#
#                                                media    brand_name  \
# 0  [{'path': 'spp-media-p1/804480cc8c2c344fa0c490...   Only & Sons
# 1  [{'path': 'spp-media-p1/207cc94776b0305d9e4da3...  Jack & Jones
# 2  [{'path': 'spp-media-p1/61cf96c837723db1892137...  Jack & Jones
# 3  [{'path': 'spp-media-p1/4c199d68f81b322e8ae746...      Pier One
# 4  [{'path': 'spp-media-p1/06d298f1f2123b26b3a417...         CELIO
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group  \
# 0  [{'key': 'discountRate', 'value': 'Jusqu’à -15...      clothing
# 1  [{'key': 'discountRate', 'value': '-32%', 'tra...      clothing
# 2  [{'key': 'discountRate', 'value': 'Jusqu’à -10...      clothing
# 3  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 4  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
#
#   delivery_promises price.original price.promotional  \
# 0                []        34,99 €           29,69 €
# 1                []        39,99 €           27,19 €
# 2                []        49,99 €           44,99 €
# 3                []        29,99 €           22,49 €
# 4                []        39,95 €           29,95 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                        True                                False
# 1                       False                                False
# 2                        True                                False
# 3                       False                                False
# 4                       False                                False
#
#    price.has_different_promotional_prices  \
# 0                                    True
# 1                                   False
# 2                                    True
# 3                                   False
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#                                              outfits amount
# 0                                                NaN    NaN
# 1                                                NaN    NaN
# 2  [{'id': '4LkTduB9R6-', 'url_key': '/outfits/4L...    NaN
# 3                                                NaN    NaN
# 4                                                NaN    NaN

# %%
total_pages = results["pagination"]["page_count"]
total_pages
# Out:
# 657

# %%
df = pd.DataFrame()
for i in range(total_pages):
    k= 84*i
    url = f"https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={84}&sort=sale"
    response = urllib.request.urlopen(url)
    results = json.load(response)
    data = json_normalize(results)
    data1 = json_normalize(data.articles[0])
    data1 = data1.set_index('sku')
    df = df.append(data1)
    print(f"getting page {i} of {total_pages}", end='\r')
    
df.head()
# Out:
# getting page 656 of 657
#                                                             name  \
# sku
# OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# JA222S1BM-C11  JORNEWSHAKEDOWN BLOCK ZIP  - veste en sweat zi...
# JA222G0VA-K11     JJILIAM JJORIGINAL - Jeans Skinny - blue denim
# PI922Q00S-C12                                       Gilet - grey
# CF522G03J-K11                        ROSLONE - Jean droit - blue
#
#                                                            sizes  \
# sku
# OS322E04A-K12  [28x30, 28x32, 28x34, 29x30, 29x32, 29x34, 30x...
# JA222S1BM-C11                                      [S, M, L, XL]
# JA222G0VA-K11  [27x30, 27x32, 28x30, 29x30, 29x32, 29x34, 30x...
# PI922Q00S-C12                            [XS, S, M, L, XXL, 6XL]
# CF522G03J-K11                           [36, 38, 40, 42, 44, 46]
#
#                                                          url_key  \
# sku
# OS322E04A-K12     only-and-sons-onsmark-pant-chino-os322e04a-k12
# JA222S1BM-C11  jack-and-jones-jornewshakedown-block-zip-veste...
# JA222G0VA-K11  jack-and-jones-jjiliam-jjoriginal-jeans-skinny...
# PI922Q00S-C12                  pier-one-gilet-grey-pi922q00s-c12
# CF522G03J-K11        celio-roslone-jean-droit-blue-cf522g03j-k11
#
#                                                            media  \
# sku
# OS322E04A-K12  [{'path': 'spp-media-p1/804480cc8c2c344fa0c490...
# JA222S1BM-C11  [{'path': 'spp-media-p1/207cc94776b0305d9e4da3...
# JA222G0VA-K11  [{'path': 'spp-media-p1/61cf96c837723db1892137...
# PI922Q00S-C12  [{'path': 'spp-media-p1/4c199d68f81b322e8ae746...
# CF522G03J-K11  [{'path': 'spp-media-p1/06d298f1f2123b26b3a417...
#
#                  brand_name  is_premium family_articles  \
# sku
# OS322E04A-K12   Only & Sons       False              []
# JA222S1BM-C11  Jack & Jones       False              []
# JA222G0VA-K11  Jack & Jones       False              []
# PI922Q00S-C12      Pier One       False              []
# CF522G03J-K11         CELIO       False              []
#
#                                                            flags  \
# sku
# OS322E04A-K12  [{'key': 'discountRate', 'value': 'Jusqu’à -15...
# JA222S1BM-C11  [{'key': 'discountRate', 'value': '-32%', 'tra...
# JA222G0VA-K11  [{'key': 'discountRate', 'value': 'Jusqu’à -10...
# PI922Q00S-C12  [{'key': 'discountRate', 'value': '-25%', 'tra...
# CF522G03J-K11  [{'key': 'discountRate', 'value': '-25%', 'tra...
#
#               product_group delivery_promises price.original  \
# sku
# OS322E04A-K12      clothing                []        34,99 €
# JA222S1BM-C11      clothing                []        39,99 €
# JA222G0VA-K11      clothing                []        49,99 €
# PI922Q00S-C12      clothing                []        29,99 €
# CF522G03J-K11      clothing                []        39,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# OS322E04A-K12           29,69 €                        True
# JA222S1BM-C11           27,19 €                       False
# JA222G0VA-K11           44,99 €                        True
# PI922Q00S-C12           22,49 €                       False
# CF522G03J-K11           29,95 €                       False
#
#                price.has_different_original_prices  \
# sku
# OS322E04A-K12                                False
# JA222S1BM-C11                                False
# JA222G0VA-K11                                False
# PI922Q00S-C12                                False
# CF522G03J-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# OS322E04A-K12                                    True
# JA222S1BM-C11                                   False
# JA222G0VA-K11                                    True
# PI922Q00S-C12                                   False
# CF522G03J-K11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# OS322E04A-K12                                      False
# JA222S1BM-C11                                      False
# JA222G0VA-K11                                      False
# PI922Q00S-C12                                      False
# CF522G03J-K11                                      False
#
#                                                          outfits amount
# sku
# OS322E04A-K12                                                NaN    NaN
# JA222S1BM-C11                                                NaN    NaN
# JA222G0VA-K11  [{'id': '4LkTduB9R6-', 'url_key': '/outfits/4L...    NaN
# PI922Q00S-C12                                                NaN    NaN
# CF522G03J-K11                                                NaN    NaN

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

# %%
df.brand_name.value_counts().head()
# Out:
# Pier One            14160
# Jack & Jones         7533
# adidas Originals     4175
# Only & Sons          3942
# Puma                 2759
# Name: brand_name, dtype: int64

# %%
df["price.original"] = df["price.original"].str.replace(",",".")
df["price.original"] = df["price.original"].str.replace("€","").str.strip()

df["price.promotional"] = df["price.promotional"].str.replace(",",".")
df["price.promotional"] = df["price.promotional"].str.replace("€","").str.strip()

# %%
df["discount"]= 100 - ((df['price.promotional'].astype(float)*100)/df['price.original'].astype(float))

# %%
df1 = df[["name","brand_name","price.original","price.promotional","discount"]].copy()
df1.head()
# Out:
#                                                             name  \
# sku
# OS322E04A-K12      ONSMARK PANT - Pantalon classique - night sky
# JA222S1BM-C11  JORNEWSHAKEDOWN BLOCK ZIP  - veste en sweat zi...
# JA222G0VA-K11     JJILIAM JJORIGINAL - Jeans Skinny - blue denim
# PI922Q00S-C12                                       Gilet - grey
# CF522G03J-K11                        ROSLONE - Jean droit - blue
#
#                  brand_name price.original price.promotional   discount
# sku
# OS322E04A-K12   Only & Sons          34.99             29.69  15.147185
# JA222S1BM-C11  Jack & Jones          39.99             27.19  32.008002
# JA222G0VA-K11  Jack & Jones          49.99             44.99  10.002000
# PI922Q00S-C12      Pier One          29.99             22.49  25.008336
# CF522G03J-K11         CELIO          39.95             29.95  25.031289

# %%
df1.sort_values(by = "discount", ascending = False).head()
# Out:
#                                        name brand_name price.original  \
# sku
# PU144A07R-A13  Baskets basses - white-black       Puma         110.00
# PU144A07R-A13  Baskets basses - white-black       Puma         110.00
# PU144A07R-A13  Baskets basses - white-black       Puma         110.00
# PU144A07R-A13  Baskets basses - white-black       Puma         110.00
# PU144A07R-A13  Baskets basses - white-black       Puma         110.00
#
#               price.promotional   discount
# sku
# PU144A07R-A13             44.95  59.136364
# PU144A07R-A13             44.95  59.136364
# PU144A07R-A13             44.95  59.136364
# PU144A07R-A13             44.95  59.136364
# PU144A07R-A13             44.95  59.136364

# %%
sum_original=df1['price.original'].astype(float).sum()
sum_discount=df1['price.promotional'].astype(float).sum()
total_disc= sum_discount/sum_original
total_disc
# Out:
# 0.7425216172408896
