# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import urllib
import requests
import pandas as pd
from pandas import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=80&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#              sku                                               name  \
# 0  N1243A132-Q12  DOWNSHIFTER 10 - Chaussures de running neutres...
# 1  NI114D0C1-Q12       AIR MAX TAILWIND IV - Baskets basses - black
# 2  AD116D0Q0-A11  CONTINENTAL 80 - Baskets basses - footwear whi...
# 3  NI126B00V-Q11              Pantalon de survêtement - black/white
# 4  C1853E00D-J11                        LOGO BELT - Ceinture - pink
#
#                                                sizes  \
# 0  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33, 3...
# 1                 [36, 36.5, 37.5, 38, 38.5, 39, 40]
# 2           [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# 3                          [6-7a, 8-9a, 10-11a, 14a]
# 4                                           [70, 80]
#
#                                              url_key  \
# 0  nike-performance-downshifter-10-chaussures-de-...
# 1  nike-sportswear-air-max-tailwind-baskets-basse...
# 2  adidas-originals-continental-80-baskets-basses...
# 3  nike-sportswear-pant-pantalon-de-survetement-n...
# 4  calvin-klein-jeans-logo-belt-ceinture-c1853e00...
#
#                                                media          brand_name  \
# 0  [{'path': 'spp-media-p1/5796add4d52037509fcbe3...    Nike Performance
# 1  [{'path': 'spp-media-p1/38eefe0d72fc3657b26c29...     Nike Sportswear
# 2  [{'path': 'spp-media-p1/ed4be21b79cd37a48909dd...    adidas Originals
# 3  [{'path': 'spp-media-p1/9559b613384838c096bc99...     Nike Sportswear
# 4  [{'path': 'spp-media-p1/460bf4e766da3f1cb8cc02...  Calvin Klein Jeans
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group amount  \
# 0  [{'key': 'discountRate', 'value': '-20%', 'tra...          shoe  144 g
# 1  [{'key': 'discountRate', 'value': 'Jusqu’à -55...          shoe    NaN
# 2  [{'key': 'discountRate', 'value': 'Jusqu’à -30...          shoe    NaN
# 3  [{'key': 'discountRate', 'value': 'Jusqu’à -25...      clothing    NaN
# 4  [{'key': 'discountRate', 'value': '-40%', 'tra...   accessoires    NaN
#
#   delivery_promises price.original price.promotional  \
# 0                []        39,95 €           31,95 €
# 1                []       139,95 €           62,95 €
# 2                []        59,95 €           41,95 €
# 3                []        44,95 €           33,65 €
# 4                []        24,95 €           14,95 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                       False                                False
# 1                        True                                False
# 2                        True                                False
# 3                        True                                False
# 4                       False                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False

# %%
print(response)
# Out:
# <http.client.HTTPResponse object at 0x7faa10745e50>

# %%
results
# Out:
# {'total_count': 17964,
#  'pagination': {'page_count': 214, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'N1243A132-Q12',
#    'name': 'DOWNSHIFTER 10 - Chaussures de running neutres - black/pink glow/anthracite/white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '31,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-performance-downshifter-10-chaussures-de-running-neutres-n1243a132-q12',
#    'media': [{'path': 'spp-media-p1/5796add4d52037509fcbe3357ed1b867/6b5e586da6bc4ee5b0334a65caf1ba15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'amount': '144 g',
#    'delivery_promises': []},
#   {'sku': 'NI114D0C1-Q12',
#    'name': 'AIR MAX TAILWIND IV - Baskets basses - black',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-tailwind-baskets-basses-ni114d0c1-q12',
#    'media': [{'path': 'spp-media-p1/38eefe0d72fc3657b26c296664062e48/49ad59c24aa343dcb1c78714634066fb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -55%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0Q0-A11',
#    'name': 'CONTINENTAL 80 - Baskets basses - footwear white/core black',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-continental-80-baskets-basses-footwear-whitecore-black-ad116d0q0-a11',
#    'media': [{'path': 'spp-media-p1/ed4be21b79cd37a48909dd091357da4b/05936f0f65ff46f8bc66c56d48439e23.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI126B00V-Q11',
#    'name': 'Pantalon de survêtement - black/white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '33,65\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-7a', '8-9a', '10-11a', '14a'],
#    'url_key': 'nike-sportswear-pant-pantalon-de-survetement-ni126b00v-q11',
#    'media': [{'path': 'spp-media-p1/9559b613384838c096bc99507d111dad/c2d68f1a86fb4473a63e0fc8b2a606cb.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'C1853E00D-J11',
#    'name': 'LOGO BELT - Ceinture - pink',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '14,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['70', '80'],
#    'url_key': 'calvin-klein-jeans-logo-belt-ceinture-c1853e00d-j11',
#    'media': [{'path': 'spp-media-p1/460bf4e766da3f1cb8cc02e3e764f038/63670d1e146245db83e899bace6b789f.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Calvin Klein Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'TO124K04Y-Q11',
#    'name': 'ESSENTIAL  - Sweatshirt - black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '42,65\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3a',
#     '4a',
#     '5a',
#     '6a',
#     '7a',
#     '8a',
#     '10a',
#     '12a',
#     '14a',
#     '16a',
#     '18-24m'],
#    'url_key': 'tommy-hilfiger-essential-sweatshirt-black-to124k04y-q11',
#    'media': [{'path': 'spp-media-p1/0a07268b130d3d10a7347b59944a3390/f803974bfc434f338d914629a613091a.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO124G05S-K11',
#    'name': 'BOYS BASIC  - T-shirt basique - sky captain',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '12,70\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '6a', '7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-boys-basic-t-shirt-basique-to124g05s-k11',
#    'media': [{'path': 'spp-media-p1/f36ea887288232a98457a4198d23b06e/6e830d2043a14ddcbbd010fa5ea94f5c.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D052-Q11',
#    'name': 'Baskets basses - black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '42,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-force-1-baskets-basses-ni114d052-q11',
#    'media': [{'path': 'spp-media-p1/7e345fb047be3bd9beacf0100972a0c9/e9db21eaceb749c1b40c1998101b08e4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD543A1H1-Q11',
#    'name': 'TERREX AX2R - Chaussures de marche - core black/vista grey',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '28.5',
#     '29',
#     '30',
#     '30.5',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35',
#     '35.5',
#     '36',
#     '38',
#     '40',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3'],
#    'url_key': 'adidas-performance-terrex-ax2r-chaussures-de-randonnee-ad543a1h1-q11',
#    'media': [{'path': 'spp-media-p1/6b794a1fa0d73bc1b922b5dcb001b730/d5971dd6f32b4eca8e04763126e6f433.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AI216C00K-302',
#    'name': 'LOLLY POP - Bottes en caoutchouc - rouge',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['26', '27', '28', '30', '31', '32', '33', '34', '35', '36', '37'],
#    'url_key': 'aigle-lolly-pop-bottes-de-pluie-rouge-ai216c00k-302',
#    'media': [{'path': 'spp-media-p1/52ded3bc8af13e65a12ec46c68f12e54/e9daf62faf944e249364a7782cdd9cdd.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Aigle',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA224G017-Q11',
#    'name': 'CLASSIC BOYS - T-shirt à manches longues - black/white',
#    'price': {'original': '25,00\xa0€',
#     'promotional': '21,25\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10-12a', '14-16a', '16-18a'],
#    'url_key': 'vans-classic-t-shirt-a-manches-longues-va224g017-q11',
#    'media': [{'path': 'spp-media-p1/7d75f936bf6a376bb49a4ec6918b5408/92c9a9556c1341e984598a45064fbc0d.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO124G05T-A11',
#    'name': 'BOYS BASIC  - T-shirt basique - bright white',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '12,70\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '6a', '7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-boys-basic-t-shirt-basique-to124g05t-a11',
#    'media': [{'path': 'spp-media-p1/13f1ef9b676c3b0d84d66f3ec7ce912b/5218252deaec498fbbf1a323049b7874.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': '1FI16D000-Q11',
#    'name': 'DISRUPTOR KIDS - Baskets basses - black',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '55,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '31', '32', '33', '34', '35'],
#    'url_key': 'fila-disruptor-kids-baskets-basses-black-1fi16d000-q11',
#    'media': [{'path': 'spp-media-p1/f55a56e3877a359c9a7db6a9e1c9b395/38f244c3ca3e440599773a91605545c9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Fila',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'CO416A03G-802',
#    'name': 'CHUCK TAYLOR AS CORE - Baskets montantes - black',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '40,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['18', '19', '20', '21', '23'],
#    'url_key': 'converse-chuck-taylor-as-core-hi-baskets-montantes-noir-co416a03g-802',
#    'media': [{'path': 'spp-media-p1/15734fce8800387a85a175a27a4438be/9f62488c39754776b2578cc271a67157.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0TO-K11',
#    'name': 'OZWEEGO SPORTS INSPIRED SHOES UNISEX - Baskets basses - sky tint',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '59,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-ozweego-sports-inspired-shoes-unisex-baskets-basses-sky-tint-ad116d0to-k11',
#    'media': [{'path': 'spp-media-p1/28d791bf4d4f3277a8523269aaf6d8f0/ba588072618b446c8383a94436674604.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'kids_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0QB-A12',
#    'name': 'SUPERSTAR - Baskets basses - footwear white/core black',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '58,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-superstar-baskets-basses-ad116d0qb-a12',
#    'media': [{'path': 'spp-media-p1/db1b92fbbdb435f59b7b114f773dfd08/05ea10a412ed45b9bb29baca12db5a3e.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA253G002-K11',
#    'name': 'Montre - blau',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '47,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'lacoste-montre-blau-la253g002-k11',
#    'media': [{'path': 'spp-media-p1/0775cd08d85f37ebbd2de447eabd8c44/66add1be162946fcaa42761fdc5b191b.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'TO123G04J-K11',
#    'name': 'GIRLS BASIC  - T-shirt basique - sky captain',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '12,70\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '6a', '7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-girls-basic-t-shirt-basique-to123g04j-k11',
#    'media': [{'path': 'spp-media-p1/30d464f7870a32fa9bd99acc66d19815/b9f9e727b961429684b30beab480aa56.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NA314F01K-T11',
#    'name': 'COCOON - Chaussures premiers pas - gold/militärgrün',
#    'price': {'original': '60,00\xa0€',
#     'promotional': '42,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['18', '19', '20', '24'],
#    'url_key': 'naturino-cocoon-chaussures-premiers-pas-goldmilitaergruen-na314f01k-t11',
#    'media': [{'path': 'spp-media-p1/f4414e33c8d63b6a883f800d2a9bfcf0/9d57442c23dc4907bf755e8ca471271e.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Naturino',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI126G00L-A11',
#    'name': 'TEE - T-shirt imprimé - white/red',
#    'price': {'original': '15,95\xa0€',
#     'promotional': '13,60\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2-3a', '3-4a', '4-5a', '5-6a'],
#    'url_key': 'nike-sportswear-tee-t-shirt-imprime-ni126g00l-a11',
#    'media': [{'path': 'spp-media-p1/804407a1d2b13a54a1e75b501494d370/d07190eece4f45bc8596c7d45da81eb7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI126K015-Q12',
#    'name': 'NIKE SPORTSWEAR RUNDHALSSHIRT FÜR ÄLTERE KINDER - Sweatshirt - black/white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6-7a', '8-9a', '10-11a'],
#    'url_key': 'nike-sportswear-repeat-crew-t-shirt-a-manches-longues-blackwhite-ni126k015-q12',
#    'media': [{'path': 'spp-media-p1/38190081558c3b959a5a51768562912e/5b9c23d786fc4434ba1ff7d8d379d77f.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D0IM-Q11',
#    'name': 'CONTINENTAL 80 - Baskets basses - core black/scarlet/collegiate navy',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '43,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '30', '31', '32', '33', '34', '35', '29 1/2', '33 1/2'],
#    'url_key': 'adidas-originals-continental-80-baskets-basses-ad116d0im-q11',
#    'media': [{'path': 'spp-media-p1/6955b7fa17b43427a0db4a1a13c0c625/7596e5cc4c0a4e27af297d9770c6e0a8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NA823L05Q-K11',
#    'name': 'NITSTAR RIKA - Veste en jean - medium blue denim',
#    'price': {'original': '26,99\xa0€',
#     'promotional': '24,29\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a',
#     '3a',
#     '4a',
#     '5a',
#     '6a',
#     '7a',
#     '8a',
#     '9a',
#     '11a',
#     '12a',
#     '13a',
#     '14a'],
#    'url_key': 'name-it-veste-en-jean-medium-blue-denim-na823l05q-k11',
#    'media': [{'path': 'spp-media-p1/729a5e6e6f713e928f5ba647039a7ac9/1bbc15aa947f419e8781abcaf6629102.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Name it',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JEF53K00P-B11',
#    'name': 'BASHFUL BUNNY - Peluche - beige',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '21,15\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['M', 'L'],
#    'url_key': 'jellycat-bashful-bunny-peluche-beige-jef53k00p-b11',
#    'media': [{'path': 'spp-media-p1/4b2f03dcbbc63d92bafb2655567b5bfe/18fdc18328a74c28b4e4533915d8b83d.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Jellycat',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
#   {'sku': 'NI116D052-Q11',
#    'name': 'REACT VISION - Baskets basses - black/white',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '98,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-react-vision-baskets-basses-blackwhite-ni116d052-q11',
#    'media': [{'path': 'spp-media-p1/b723a859cd4f384aa8eb9f73be231e0a/5fe45c9197844dc8a50cce61f888aba0.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA214D01C-A11',
#    'name': 'CARNABY EVO BL 1 SPI - Baskets basses - white/navy',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '46,65\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19', '20', '21', '22', '23', '24', '25', '26', '27'],
#    'url_key': 'lacoste-carnaby-evo-bl-1-spi-baskets-basses-white-navy-la214d01c-a11',
#    'media': [{'path': 'spp-media-p1/fda0fe0ac98a3be3b48962ca6e8e78dd/78c5836eded5486babbcb83b09e43df1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0BG-Q11',
#    'name': 'COURT BOROUGH MID 2 - Baskets montantes - black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '44,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-sportswear-court-borough-mid-boot-baskets-montantes-ni114d0bg-q11',
#    'media': [{'path': 'spp-media-p1/00bb42b41c813f5c9d61a6ad6b6482e1/02e50155395d416ca925e177abc0b0fc.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0DI-Q11',
#    'name': 'RENEW 55 - Baskets basses - black/white/anthracite',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '55,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-renew-element-55-baskets-basses-ni114d0di-q11',
#    'media': [{'path': 'spp-media-p1/262e847f351d35e19495e171d7126d0b/d14c8ba205534e639f3fca73673f37fd.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GE114E02F-K11',
#    'name': 'EACH BOY - Chaussures premiers pas - dark navy',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '53,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['23', '24', '25'],
#    'url_key': 'geox-each-boy-chaussures-a-scratch-dark-navy-ge114e02f-k11',
#    'media': [{'path': 'spp-media-p1/9a1b311ad904385285d4b501237ebacc/1e4f61eaee3d49ed9535793c63c72096.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Geox',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE226K003-G11',
#    'name': 'BATWING SCREENPRINT HOODIE - Sweat à capuche - red/white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-batwing-screenprint-hoodie-sweatshirt-le226k003-g11',
#    'media': [{'path': 'spp-media-p1/711e633be3fe3fb7b85793c2b4977978/703c5b65be184de2b7390b0e80153d64.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'JAN24C00F-K11',
#    'name': 'Short - navy blazer',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '15,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a', '12a', '14a'],
#    'url_key': 'jack-and-jones-junior-jji-shark-short-navy-blazer-jan24c00f-k11',
#    'media': [{'path': 'spp-media-p1/91a163d456bc336a8cfba43832ad7217/074138b380034831af60a3640707f3ea.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones Junior',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D03T-Q11',
#    'name': 'GAZELLE - Baskets basses - core black/white/gold metallic',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '41,15\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '30',
#     '31',
#     '32',
#     '33',
#     '34',
#     '35',
#     '28 1/2',
#     '29 1/2',
#     '33 1/2'],
#    'url_key': 'adidas-originals-gazelle-baskets-basses-ad116d03t-q11',
#    'media': [{'path': 'spp-media-p1/c90df34c9906321aaf9aa8722d9adb4e/e156fa6716294151b7c4dcbb7163afa7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0DN-A11',
#    'name': 'AIR MAX 270 REACT - Baskets basses - white/metallic silver',
#    'price': {'original': '134,95\xa0€',
#     'promotional': '66,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-270-react-baskets-basses-whitemetallic-silver-ni114d0dn-a11',
#    'media': [{'path': 'spp-media-p1/32e339e84ddf337ab6c22476ab318861/74761fc6906442ac90565a577b3ca24c.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D07C-Q12',
#    'name': 'AIR MAX 270 - Baskets basses - black/white/anthracite',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '107,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-270-baskets-basses-blackwhiteanthracite-ni114d07c-q12',
#    'media': [{'path': 'spp-media-p1/eec5043cfa6633299fe47b8237c76681/4325c05e7ea64d29a8dfa95d9d50c95c.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO124G080-C12',
#    'name': 'ESSENTIAL TEE - T-shirt à manches longues - grey',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '19,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['5a', '8a', '10a', '12a', '14a', '16a', '18-24m'],
#    'url_key': 'tommy-hilfiger-essential-tee-t-shirt-a-manches-longues-grey-to124g080-c12',
#    'media': [{'path': 'spp-media-p1/f65f3a4f565833039da3f0ce4120877f/7e44ca641ab94226b64f47254520e6e1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D0SS-A12',
#    'name': 'STAN SMITH SPORTS INSPIRED SHOES - Baskets basses - footwear white/haze coral',
#    'price': {'original': '46,95\xa0€',
#     'promotional': '37,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19', '20', '21', '22', '23', '24', '25', '26', '27'],
#    'url_key': 'adidas-originals-stan-smith-sports-inspired-shoes-baskets-basses-footwear-whitehaze-coral-ad116d0ss-a12',
#    'media': [{'path': 'spp-media-p1/525cfe5b176f320bbe945fbb7fa99d2b/c4b43b92243647a5bd0b7783e9fb61f6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0EW-Q12',
#    'name': 'AIR MAX FUSION UNISEX - Baskets basses - black',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '52,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-nike-air-max-fusion-baskets-basses-ni114d0ew-q12',
#    'media': [{'path': 'spp-media-p1/b9c6889db1a731eca4efdf6192f3571d/8ee99782136f49af93d7d0b95f3e9427.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'CO413C01C-002',
#    'name': 'CHUCK TAYLOR ALL STAR  - Baskets montantes - optical white',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '44,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27', '28', '28.5', '29', '30', '31', '31.5', '32', '33', '33.5'],
#    'url_key': 'converse-chuck-taylor-as-core-baskets-montantes-blanc-co413c01c-002',
#    'media': [{'path': 'spp-media-p1/437f6d75b58733dca67391d388b58e67/cef38e35b879472aa030517bd26773ed.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D07P-J11',
#    'name': 'GAZELLE  - Baskets basses - ice pink/footwear white/gold metallic',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-gazelle-baskets-basses-ad116d07p-j11',
#    'media': [{'path': 'spp-media-p1/aafa23dd0bdf305c90f8101f8ac87314/958290e3633f4aee96f5c01d4ccd68ea.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'PU143E078-Q11',
#    'name': 'EVOSTRIPE PANTS - Pantalon de survêtement - black',
#    'price': {'original': '35,00\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'puma-evostripe-pants-pantalon-de-survetement-black-pu143e078-q11',
#    'media': [{'path': 'spp-media-p1/4ab817139b91377ab4b22a1ce386ad0a/29ae81976a6d4378a86b46fd00001ea0.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-32%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD543A27B-A11',
#    'name': "TENSAUR UNISEX - Chaussures d'entraînement et de fitness - footwear white/core black",
#    'price': {'original': '29,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '29',
#     '30',
#     '30.5',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35',
#     '40',
#     '36 2/3',
#     '39 1/3'],
#    'url_key': 'adidas-performance-vector-chaussures-dentrainement-et-de-fitness-ad543a27b-a11',
#    'media': [{'path': 'spp-media-p1/4db3fb9a91463e0dac66ab61c4ef8ff1/7c4908611fe549119241aa6d076de029.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1243A106-A11',
#    'name': 'TEAM HUSTLE - Chaussures de basket - white/black/volt',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-performance-team-hustle-chaussures-de-basket-whiteblackvolt-n1243a106-a11',
#    'media': [{'path': 'spp-media-p1/2afef4fe4962310d958dc528cbd048e1/ec1c49f6e6904d4b8525e25787900ebd.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI124G00J-G11',
#    'name': 'TEE BABY - T-shirt imprimé - university red',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '11,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['12m', '18m', '24m'],
#    'url_key': 'nike-sportswear-tee-baby-t-shirt-imprime-ni124g00j-g11',
#    'media': [{'path': 'spp-media-p1/3a2f5b2ce5c73db9b2748b6dde04f247/2fccb77a8b8d45df9f48df181b4f6d1e.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD543A27B-Q12',
#    'name': "TENSAUR UNISEX - Chaussures d'entraînement et de fitness - core black/footwear white",
#    'price': {'original': '29,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28',
#     '28.5',
#     '29',
#     '30',
#     '30.5',
#     '31',
#     '31.5',
#     '33',
#     '33.5',
#     '34',
#     '35',
#     '35.5'],
#    'url_key': 'adidas-performance-vector-chaussures-dentrainement-et-de-fitness-ad543a27b-q12',
#    'media': [{'path': 'spp-media-p1/7bad92813c5e3f46bf17380e5d5f1518/a2d84ddd41f945d5a02719082cc26d13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA213D01I-A11',
#    'name': 'CARNABY EVO - Baskets basses - white/pink',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'lacoste-carnaby-evo-baskets-basses-whitepink-la213d01i-a11',
#    'media': [{'path': 'spp-media-p1/a882c43ea4f331c88255e90eed43cbd5/c325bfee19f64424bd323d09c0a4593a.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'VA216B00K-N11',
#    'name': 'CLASSIC - Mocassins - military olive/true white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '31,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27', '28', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'vans-classic-baskets-basses-military-olivetrue-white-va216b00k-n11',
#    'media': [{'path': 'spp-media-p1/761bfc6e8b9332b6923f7406da06a7e7/69720de11e414285ad3623f16f365d9a.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'JAN24K00K-Q11',
#    'name': 'JJELOGO SWEAT HOOD 2 COL NOOS JR - Sweat à capuche - black',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '21,15\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a', '12a', '14a', '16a'],
#    'url_key': 'jack-and-jones-junior-jjelogo-hood-sweatshirt-jan24k00k-q11',
#    'media': [{'path': 'spp-media-p1/a5ad7471a8923555bb9c8deacc40ba5f/29306a74ef7d4863b88b2f446ed190fc.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Jack & Jones Junior',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE223G03L-K11',
#    'name': 'BATWING - T-shirt imprimé - peacoat/tea tree pink',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '16,15\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['6a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-batwing-tee-t-shirt-imprime-le223g03l-k11',
#    'media': [{'path': 'spp-media-p1/302132af35c93ec6a3229008df130194/386bfd8182b24eb0ba568dabfe9ad61e.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO124G05S-K12',
#    'name': 'BOYS BASIC  - T-shirt basique - dark allure heather',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '13,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '6a', '7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-boys-basic-t-shirt-basique-to124g05s-k12',
#    'media': [{'path': 'spp-media-p1/5b527c20db1332edb5bd8671d24faaa8/32f220214abb44708bedd4c37ed72425.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'N1243A132-K11',
#    'name': 'DOWNSHIFTER 10 - Chaussures de running neutres - deep royal blue/white/hyper blue',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '31,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '30', '31.5', '33', '34'],
#    'url_key': 'nike-performance-downshifter-10-chaussures-de-running-neutres-n1243a132-k11',
#    'media': [{'path': 'spp-media-p1/88c0aa17bd273e15aae4f340308599cd/739e5116a9e9452d9e93021fecb6dbce.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'amount': '145 g',
#    'delivery_promises': []},
#   {'sku': 'TO124K053-C11',
#    'name': 'ESSENTIAL HOODIE - Sweat à capuche - grey',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '49,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3a', '4a', '5a', '6a', '7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-essential-hoodie-sweatshirt-grey-to124k053-c11',
#    'media': [{'path': 'spp-media-p1/bfcd9e09f77a30b5abebfab30e1caac9/b8ad4c145fcd45f99332c7880d3d2355.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsabilité',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO124K04Y-C11',
#    'name': 'ESSENTIAL  - Sweatshirt - grey',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '44,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-essential-sweatshirt-to124k04y-c11',
# ...
#     {'key': 'SMC', 'label': 'Smitten Organic', 'is_family': False},
#     {'key': 'SMA', 'label': 'Småfolk', 'is_family': False},
#     {'key': 'SG9', 'label': 'Soft Gallery', 'is_family': False},
#     {'key': 'SY9',
#      'label': 'Sonia Rykiel',
#      'family_id': 'SORY',
#      'is_family': False},
#     {'key': 'SO6', 'label': 'Sorel', 'is_family': False},
#     {'key': 'SOH', 'label': 'South Beach', 'is_family': False},
#     {'key': '1SP', 'label': 'Speedo', 'is_family': False},
#     {'key': 'SY0', 'label': 'Spyder', 'is_family': False},
#     {'key': 'STF', 'label': 'Staccato', 'is_family': False},
#     {'key': 'ST02', 'label': 'Steiff', 'is_family': True},
#     {'key': 'S15',
#      'label': 'Steiff Collection',
#      'family_id': 'ST02',
#      'is_family': False},
#     {'key': 'STZ',
#      'label': 'Steiff Shoes',
#      'family_id': 'ST02',
#      'is_family': False},
#     {'key': 'S0Y',
#      'label': 'Stella McCartney',
#      'family_id': 'ST03',
#      'is_family': False},
#     {'key': 'ST3',
#      'label': 'Steve Madden',
#      'family_id': 'ST01',
#      'is_family': False},
#     {'key': 'SUF', 'label': 'Sunnylife', 'is_family': False},
#     {'key': 'SUN', 'label': 'Sunuva', 'is_family': False},
#     {'key': 'SU2', 'label': 'Superdry', 'is_family': False},
#     {'key': 'LE3', 'label': 'Superfit', 'is_family': False},
#     {'key': 'SU1', 'label': 'Superga', 'is_family': False},
#     {'key': 'SUS', 'label': 'SuperRebel', 'is_family': False},
#     {'key': 'TE2', 'label': 'Teva', 'is_family': False},
#     {'key': 'THV', 'label': 'THE ANIMALS OBSERVATORY', 'is_family': False},
#     {'key': 'THN', 'label': 'The New', 'is_family': False},
#     {'key': 'TH3', 'label': 'The North Face', 'is_family': False},
#     {'key': 'T1B', 'label': 'The Rocks Push', 'is_family': False},
#     {'key': 'THO', 'label': 'THE WHITE BRAND', 'is_family': False},
#     {'key': 'TF3', 'label': 'Tiffosi', 'is_family': False},
#     {'key': 'TI1', 'label': 'Timberland', 'is_family': False},
#     {'key': 'TIC', 'label': 'TINYCOTTONS', 'is_family': False},
#     {'key': 'TOP', 'label': 'Tobias & The Bear', 'is_family': False},
#     {'key': '4JO', 'label': 'Tom Joule', 'is_family': False},
#     {'key': 'TO2',
#      'label': 'TOM TAILOR',
#      'family_id': 'TOMT',
#      'is_family': False},
#     {'key': 'TO1',
#      'label': 'Tommy Hilfiger',
#      'family_id': 'TOMM',
#      'is_family': False},
#     {'key': 'TO3', 'label': 'TOMS', 'is_family': False},
#     {'key': 'TRI', 'label': 'TrollKids', 'is_family': False},
#     {'key': 'TU4', 'label': "Tumble 'n dry", 'is_family': False},
#     {'key': 'TUA', 'label': 'Turtledove', 'is_family': False},
#     {'key': 'UG1', 'label': 'UGG', 'is_family': False},
#     {'key': 'UH1', 'label': 'Uhlsport', 'is_family': False},
#     {'key': 'UM1', 'label': 'Umbro', 'family_id': 'UM00', 'is_family': False},
#     {'key': 'UNG', 'label': 'Unauthorized', 'is_family': False},
#     {'key': 'UN2', 'label': 'Under Armour', 'is_family': False},
#     {'key': 'UN1', 'label': 'Unisa', 'family_id': 'UN00', 'is_family': False},
#     {'key': 'VA2', 'label': 'Vans', 'is_family': False},
#     {'key': 'VA4', 'label': 'Vaude', 'is_family': False},
#     {'key': 'VJ2', 'label': 'Veja', 'is_family': False},
#     {'key': '1VE', 'label': 'Versace', 'is_family': False},
#     {'key': 'VI2', 'label': 'Victoria Shoes', 'is_family': False},
#     {'key': 'VI1', 'label': 'Viking', 'is_family': False},
#     {'key': 'V11', 'label': 'Vilebrequin', 'is_family': False},
#     {'key': 'V20', 'label': 'Vingino', 'is_family': False},
#     {'key': '1VG', 'label': 'VOGUE Eyewear', 'is_family': False},
#     {'key': 'V19', 'label': 'Volcom', 'is_family': False},
#     {'key': 'WAG', 'label': 'Walkiddy', 'is_family': False},
#     {'key': 'WAE', 'label': 'Walnut', 'is_family': False},
#     {'key': 'BAS',
#      'label': 'WAUW CAPOW by Bangbang Copenhagen',
#      'is_family': False},
#     {'key': 'WF5', 'label': 'WE Fashion', 'is_family': False},
#     {'key': 'WHA', 'label': 'Wheat', 'is_family': False},
#     {'key': 'WH9', 'label': 'White Stuff', 'is_family': False},
#     {'key': 'WO8', 'label': 'Woden', 'is_family': False},
#     {'key': 'WO4', 'label': 'Wood Wood', 'is_family': False},
#     {'key': 'XT1', 'label': 'XTI', 'is_family': False},
#     {'key': 'Z21',
#      'label': 'Zadig & Voltaire',
#      'family_id': 'ZA00',
#      'is_family': False},
#     {'key': 'ZAF',
#      'label': 'Zalando Essentials Kids',
#      'family_id': 'ZAES',
#      'is_family': False},
#     {'key': 'Z10', 'label': 'Ziener', 'is_family': False},
#     {'key': 'ZOA', 'label': 'Zoe Leggings', 'is_family': False},
#     {'key': 'ZOC', 'label': 'Zoobug', 'is_family': False},
#     {'key': 'PO9', 'label': '3 Pommes', 'is_family': False},
#     {'key': '880', 'label': '8848 Altitude', 'is_family': False}],
#    'family_key': 'brand_families'},
#   {'key': 'colors',
#    'label': 'Couleur',
#    'url_key': 'color',
#    'kind': 'values',
#    'values': [{'key': 'BLACK', 'label': 'noir'},
#     {'key': 'BROWN', 'label': 'marron'},
#     {'key': 'BEIGE', 'label': 'beige'},
#     {'key': 'GRAY', 'label': 'gris'},
#     {'key': 'WHITE', 'label': 'blanc'},
#     {'key': 'BLUE', 'label': 'bleu'},
#     {'key': 'PETROL', 'label': 'bleu pétrole'},
#     {'key': 'TURQUOISE', 'label': 'turquoise'},
#     {'key': 'GREEN', 'label': 'vert'},
#     {'key': 'OLIVE', 'label': 'vert olive'},
#     {'key': 'YELLOW', 'label': 'jaune'},
#     {'key': 'ORANGE', 'label': 'orange'},
#     {'key': 'RED', 'label': 'rouge'},
#     {'key': 'PINK', 'label': 'rose'},
#     {'key': 'PURPLE', 'label': 'violet'},
#     {'key': 'GOLD', 'label': 'doré'},
#     {'key': 'SILVER', 'label': 'argenté'},
#     {'key': 'MULTICOLORED', 'label': 'multicolore'}]},
#   {'key': 'genders',
#    'label': 'Sexe',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'FEMALE', 'label': 'Fille'},
#     {'key': 'MALE', 'label': 'Garçon'}]},
#   {'key': 'age_groups',
#    'label': 'Âge',
#    'url_key': 'gender',
#    'kind': 'values',
#    'values': [{'key': 'BABIES', 'label': 'Bébé'},
#     {'key': 'KIDS', 'label': 'Enfant'},
#     {'key': 'TEEN', 'label': 'Ado'}]},
#   {'key': 'prices',
#    'label': 'Prix',
#    'url_key': 'price',
#    'kind': 'range',
#    'range': {'min': 4,
#     'max': 500,
#     'unit': {'symbol': '€', 'position': 'suffix'}}},
#   {'key': 'sales',
#    'label': 'Promos',
#    'url_key': 'sale',
#    'kind': 'single_value',
#    'values': [{'key': 'SALE', 'label': 'Voir les promos'}]},
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'other', 'label': 'Autres matières'},
#     {'key': 'cashmere', 'label': 'Cachemire'},
#     {'key': 'caoutchouc', 'label': 'Caoutchouc'},
#     {'key': 'cotton', 'label': 'Coton'},
#     {'key': 'pure_cotton', 'label': 'coton (100%)'},
#     {'key': 'crocheted', 'label': 'Crocheté'},
#     {'key': 'leather', 'label': 'Cuir'},
#     {'key': 'cord', 'label': 'Côtelé'},
#     {'key': 'denim', 'label': 'Denim'},
#     {'key': 'lace', 'label': 'Dentelle'},
#     {'key': 'felt', 'label': 'Feutre'},
#     {'key': 'hardshell', 'label': 'Hardshell'},
#     {'key': 'imitation_leather', 'label': 'Imitation cuir'},
#     {'key': 'jersey', 'label': 'Jersey'},
#     {'key': 'wool', 'label': 'Laine'},
#     {'key': 'linen', 'label': 'Lin'},
#     {'key': 'pure_lyocell', 'label': 'lyocell (100%)'},
#     {'key': 'mesh', 'label': 'Mesh'},
#     {'key': 'chiffon', 'label': 'mousseline'},
#     {'key': 'sequins', 'label': 'paillettes'},
#     {'key': 'fleece', 'label': 'Polaire'},
#     {'key': 'polyester', 'label': 'Polyester'},
#     {'key': 'satin', 'label': 'Satin'},
#     {'key': 'softshell', 'label': 'Softshell'},
#     {'key': 'silk', 'label': 'Soie'},
#     {'key': 'rib', 'label': 'Strié'},
#     {'key': 'sweat', 'label': 'Sweat'},
#     {'key': 'synthetic', 'label': 'Synthétique'},
#     {'key': 'textile', 'label': 'Textile'},
#     {'key': 'braided', 'label': 'tressé'},
#     {'key': 'knitted_fabric', 'label': 'tricots'},
#     {'key': 'varnish', 'label': 'Verni'},
#     {'key': 'viscose', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsabilité',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsabilité'}],
#    'group_id': 'sustainable',
#    'description': 'Retrouvez la planète au cœur même de notre sélection mode et beauté.'},
#   {'key': 'multipack',
#    'label': 'Nombre de multi-packs',
#    'url_key': 'multipack',
#    'kind': 'values',
#    'values': [{'key': '2', 'label': '2 packs'},
#     {'key': '3', 'label': '3 packs'},
#     {'key': '4', 'label': '4 packs'},
#     {'key': '5', 'label': '5 packs'},
#     {'key': '6', 'label': '6 packs'},
#     {'key': '7', 'label': '7 packs'},
#     {'key': '9', 'label': '9 packs'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'camouflage', 'label': 'camouflage'},
#     {'key': 'checked', 'label': 'carreaux'},
#     {'key': 'herring_bone', 'label': 'chevrons'},
#     {'key': 'flecked', 'label': 'chiné'},
#     {'key': 'plain', 'label': 'couleur unie'},
#     {'key': 'gradient', 'label': 'dégradé'},
#     {'key': 'burnout', 'label': 'dévoré'},
#     {'key': 'pinstripe', 'label': 'fines rayures'},
#     {'key': 'floral', 'label': 'floral'},
#     {'key': 'print', 'label': 'imprimé'},
#     {'key': 'animal_print', 'label': 'imprimé animal'},
#     {'key': 'leopard', 'label': 'imprimé léopard'},
#     {'key': 'photo_print', 'label': 'imprimé photo'},
#     {'key': 'colored', 'label': 'multicolore'},
#     {'key': 'paisley', 'label': 'Paisley/cachemire'},
#     {'key': 'striped', 'label': 'rayures'},
#     {'key': 'polka_dot', 'label': 'à pois'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'kids_sneaker_releases', 'label': 'Hot Sneaker Drops'}]},
#   {'key': 'shipped_by_zalando',
#    'label': 'Expédié par Zalando',
#    'url_key': 'shipped_by_zalando',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Expédié par Zalando'}],
#    'group_id': 'delivery'},
#   {'key': 'fr_delivery_24h',
#    'label': 'Livraison 24H',
#    'url_key': 'livraison-24h',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Livraison 24H'}],
#    'group_id': 'delivery'}],
#  'total_article_count': 17966,
#  'filter_groups': [],
#  'plusStatus': 'non-eligible',
#  'categoryTree': [{'label': 'Promotions',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/?order=sale',
#      'children': [],
#      'article_count': 11475},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/?order=sale',
#      'children': [],
#      'article_count': 4626},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/?order=sale',
#      'children': [],
#      'article_count': 2458},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/?order=sale',
#      'children': [],
#      'article_count': 954},
#     {'label': 'Espace Créateurs',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/?order=sale',
#      'children': [],
#      'article_count': 1699}],
#    'article_count': 17959}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/?order=sale'},
#     {'label': 'Promotions',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promotions',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/?order=sale',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/?order=sale',
#   'reset_url': '/promo-enfant/?order=sale',
#   'app_url': '?urlKey=promo-enfant&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promotions',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/?order=sale',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False,
#   'topTeaserPlaceholder': True,
#   'salesBannerCountdown': False,
#   'lazyArticleImages': False,
#   'useImg01': True},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'search-dialog-mobile': [14],
#   'search-dialog-mobile-premium': [10],
#   'search-dialog-fullwidth': [24],
#   'search-dialog-premium': [16],
#   'search-dialog': [18],
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43],
#   'style-profile-follow-brands-banner': 6,
#   'style-profile-follow-brands-banner-mobile': 4,
#   'ingrid-teaser': 6,
#   'ingrid-premium-teaser': 5,
#   'ingrid-mobile-teaser': 4,
#   'ingrid-premium-mobile-teaser': 3},
#  'prideEnabled': False,
#  'lazyArticleImages': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'teaser': None,
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
total_pages=results['pagination']
total_pages
# Out:
# {'page_count': 214, 'current_page': 2, 'per_page': 84}

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urllib.request.urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    print(f"getting page {i} of {total_pages}", end='\r')

df.head()
# Out:
# getting page 213 of 214
#                                                             name  \
# sku
# AD116D008-A11          STAN SMITH - Baskets basses - white/green
# LE226G007-C11  BATWING - T-shirt à manches longues - grey hea...
# AD116D07G-A11  STAN SMITH CF I - Chaussures premiers pas - wh...
# NI114D0CS-A11            COURT BOROUGH  - Baskets basses - white
# AD116D0MP-A11  STAN SMITH - Baskets basses - footwear white/c...
#
#                                                            sizes  \
# sku
# AD116D008-A11           [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# LE226G007-C11                       [6a, 8a, 10a, 12a, 14a, 16a]
# AD116D07G-A11               [19, 20, 21, 22, 23, 24, 25, 26, 27]
# NI114D0CS-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD116D0MP-A11  [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3, 3...
#
#                                                          url_key  \
# sku
# AD116D008-A11  adidas-originals-stan-smith-baskets-basses-bla...
# LE226G007-C11  levisr-batwing-tee-t-shirt-a-manches-longues-l...
# AD116D07G-A11  adidas-originals-stan-smith-cf-i-baskets-basse...
# NI114D0CS-A11  nike-sportswear-court-borough-baskets-basses-n...
# AD116D0MP-A11  adidas-originals-stan-smith-baskets-basses-foo...
#
#                                                            media  \
# sku
# AD116D008-A11  [{'path': 'spp-media-p1/6e77790477903cb2943858...
# LE226G007-C11  [{'path': 'spp-media-p1/dd9fded32dde3b17b0486c...
# AD116D07G-A11  [{'path': 'spp-media-p1/ce39b604a97b373bbe8e46...
# NI114D0CS-A11  [{'path': 'spp-media-p1/0b5fec9e420b37099ccfe6...
# AD116D0MP-A11  [{'path': 'spp-media-p1/e35946364032394ea54a0f...
#
#                      brand_name  is_premium family_articles  \
# sku
# AD116D008-A11  adidas Originals       False              []
# LE226G007-C11           Levi's®       False              []
# AD116D07G-A11  adidas Originals       False              []
# NI114D0CS-A11   Nike Sportswear       False              []
# AD116D0MP-A11  adidas Originals       False              []
#
#                                                            flags  \
# sku
# AD116D008-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -30...
# LE226G007-C11  [{'key': 'discountRate', 'value': '-25%', 'tra...
# AD116D07G-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...
# NI114D0CS-A11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# AD116D0MP-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -20...
#
#               product_group delivery_promises price.original  \
# sku
# AD116D008-A11          shoe                []        64,95 €
# LE226G007-C11      clothing                []        21,95 €
# AD116D07G-A11          shoe                []        49,95 €
# NI114D0CS-A11          shoe                []        34,95 €
# AD116D0MP-A11          shoe                []        64,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# AD116D008-A11           45,45 €                        True
# LE226G007-C11           16,45 €                        True
# AD116D07G-A11           37,45 €                        True
# NI114D0CS-A11           27,95 €                       False
# AD116D0MP-A11           51,95 €                        True
#
#                price.has_different_original_prices  \
# sku
# AD116D008-A11                                False
# LE226G007-C11                                False
# AD116D07G-A11                                False
# NI114D0CS-A11                                False
# AD116D0MP-A11                                False
#
#                price.has_different_promotional_prices  \
# sku
# AD116D008-A11                                    True
# LE226G007-C11                                    True
# AD116D07G-A11                                    True
# NI114D0CS-A11                                   False
# AD116D0MP-A11                                    True
#
#                price.has_discount_on_selected_sizes_only amount condition  \
# sku
# AD116D008-A11                                      False    NaN       NaN
# LE226G007-C11                                      False    NaN       NaN
# AD116D07G-A11                                      False    NaN       NaN
# NI114D0CS-A11                                      False    NaN       NaN
# AD116D0MP-A11                                      False    NaN       NaN
#
#               condition_key
# sku
# AD116D008-A11           NaN
# LE226G007-C11           NaN
# AD116D07G-A11           NaN
# NI114D0CS-A11           NaN
# AD116D0MP-A11           NaN

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Boboli'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Naturino'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0].head()
# Out:
# brand_name
# Angel & Rocket      0.0
# Belstaff            0.0
# Bergstein           0.0
# Bikkembergs Kids    0.0
# Bogs                0.0
# Name: discount_amount, dtype: float64
